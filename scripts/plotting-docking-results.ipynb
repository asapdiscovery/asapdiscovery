# %%
import plotly.express as ex
import pandas as pd
import numpy as np

# %%
fn = "docking_results.csv"

# %%
df = pd.read_csv(fn).fillna("-1")

# %%
df
# Out:
#       Unnamed: 0         Compound_ID  Crystal ID Chain ID MCSS Rank  \
# 0              0  ADA-UCB-6c2cb422-1  Mpro-P2028       0B       0.0
# 1              1  ADA-UCB-6c2cb422-1  Mpro-P2185       0B       9.0
# 2              2  ADA-UCB-6c2cb422-1  Mpro-P0764       0A       1.0
# 3              3  ADA-UCB-6c2cb422-1  Mpro-P0098       0A       3.0
# 4              4  ADA-UCB-6c2cb422-1  Mpro-P2205       0A       7.0
# ...          ...                 ...         ...      ...       ...
# 3987        3987  VLA-UNK-cf7facf1-1  Mpro-P0022       0A       1.0
# 3988        3988  VLA-UNK-cf7facf1-1  Mpro-P0811       0B       4.0
# 3989        3989  VLA-UNK-cf7facf1-1  Mpro-P0143       0A        -1
# 3990        3990  VLA-UNK-cf7facf1-1  Mpro-P0017       0A       9.0
# 3991        3991  VLA-UNK-cf7facf1-1  Mpro-P0143       0B        -1
#
#                                            SDF Filename  \
# 0     kinoml_OEDockingFeaturizer_MPRO_Mpro-P2028_0B_...
# ...

# %%
ex.scatter(df, x="MCSS Rank", y="RMSD", color="Compound_ID", hover_data=["Crystal ID", "Reference SDF", "Chain ID"])
# Out:
# <div>                            <div id="3140be79-146a-4d74-959f-09c0aa166ee8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3140be79-146a-4d74-959f-09c0aa166ee8")) {                    Plotly.newPlot(                        "3140be79-146a-4d74-959f-09c0aa166ee8",                        [{"customdata":[["Mpro-P2028","/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P2005_0A/Mpro-P2005_0A.sdf","0B"],["Mpro-P2185","/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P2005_0A/Mpro-P2005_0A.sdf","0B"],["Mpro-P0764","/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P2005_0A/Mpro-P2005_0A.sdf","0A"],["Mpro-P0098","/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P2005_0A/Mpro-P2005_0A.sdf","0A"],["Mpro-P2205","/User
# ...

# %%
df[df['Compound_ID'] == 'MAT-POS-5d65ec79-1']["Reference SDF"][2263]
# Out:
# '/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P0097_1A/Mpro-P0097_1A.sdf'

# %%
ex.scatter(df, x="MCSS Rank", y="RMSD", color="Compound_ID", hover_data=["Crystal ID", "Reference SDF"], facet_col="Chain ID")
# Out:
# <div>                            <div id="2b55957b-9869-4070-bd07-20d94e90f2d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b55957b-9869-4070-bd07-20d94e90f2d4")) {                    Plotly.newPlot(                        "2b55957b-9869-4070-bd07-20d94e90f2d4",                        [{"customdata":[["Mpro-P2028","/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P2005_0A/Mpro-P2005_0A.sdf"],["Mpro-P2185","/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P2005_0A/Mpro-P2005_0A.sdf"],["Mpro-P0764","/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P2005_0A/Mpro-P2005_0A.sdf"],["Mpro-P2210","/Users/alexpayne/lilac-mount-point/fragalysis/aligned/Mpro-P2005_0A/Mpro-P2005_0A.sdf"]],"hovertemplate":"Compound_ID=ADA-UCB-6c
# ...

# %%
ex.histogram(df, x="RMSD", color="Chain ID", barmode='overlay', facet_col="MCSS Rank")
# Out:
# <div>                            <div id="3ccf00a0-8a1a-45aa-93d3-c9ad7f6dcd58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ccf00a0-8a1a-45aa-93d3-c9ad7f6dcd58")) {                    Plotly.newPlot(                        "3ccf00a0-8a1a-45aa-93d3-c9ad7f6dcd58",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Chain ID=0B<br>MCSS Rank=0.0<br>RMSD=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0B","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"0B","offsetgroup":"0B","orientation":"v","showlegend":true,"x":[7.874266643940498,0.5028386855406252,0.903422555859058,1.0264294413253885,0.7254471864370028,0.7304572481266521,1.4416460252136043,0.8060268602301988,1.979924576971786,0.75531661658
# ...
